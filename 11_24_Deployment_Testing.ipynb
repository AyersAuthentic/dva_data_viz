# %%
import pandas as pd

# %%
df = pd.read_csv('https://storage.googleapis.com/additional-data/newCummulatedClean/new_CMaster_HPS_CDC_CPS_NYC_Vaccinated.csv')
# Out:
# /Users/dev/miniforge3/envs/ml4t/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    Unnamed: 0   YMFIPS_x  YEAR MONTH  FIPS    STATE STATE_CODE  TBIRTH_YEAR  \
# 0           0  2021-9-01  2021   SEP   1.0  Alabama         AL         1941
# 1           1  2021-9-01  2021   SEP   1.0  Alabama         AL         1973
# 2           2  2021-9-13  2021   SEP  13.0  Georgia         GA         1970
# 3           3  2021-9-01  2021   SEP   1.0  Alabama         AL         1969
# 4           4  2021-9-01  2021   SEP   1.0  Alabama         AL         1977
#
#    EEDUC  THHLD_NUMPER  ...  CDCCOUNT  REMPCT  people_vaccinated  \
# 0      7             1  ...   44878.0   0.032          2583590.0
# 1      4             3  ...   44878.0   0.032          2583590.0
# 2      4             1  ...   58816.0   0.043          5828605.0
# 3      3             6  ...   44878.0   0.032          2583590.0
# 4      4             3  ...   44878.0   0.032          2583590.0
#
#    people_vaccinated_per_hundred  people_fully_vaccinated  \
# ...

# %%
new_df = pd.read_csv("https://storage.googleapis.com/additional-data/CummulatedClean_Nov22_with_lock/0_CMaster2_HPS_CDC_CPS_Vaccinated_with_lock.csv")
# Out:
# /Users/dev/miniforge3/envs/ml4t/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
new_df.head()
# Out:
#    Unnamed: 0     YMFIPS  YEAR MONTH  FIPS STATE LOCATION  TBIRTH_YEAR  EEDUC  \
# 0           0  2021-9-01  2021   SEP     1    AL  Alabama         1941      7
# 1           1  2021-9-01  2021   SEP     1    AL  Alabama         1973      4
# 2           2  2021-9-13  2021   SEP    13    GA  Georgia         1970      4
# 3           3  2021-9-01  2021   SEP     1    AL  Alabama         1969      3
# 4           4  2021-9-01  2021   SEP     1    AL  Alabama         1977      4
#
#    THHLD_NUMPER  ...  MORTLMTH  MORTCONF  INCOME  REMPCT  CDCCOUNT  \
# 0             1  ...       -88       -88       4   0.032   44878.0
# 1             3  ...         1         4       6   0.032   44878.0
# 2             1  ...         1         3       1   0.043   58816.0
# 3             6  ...       -88       -88     -88   0.032   44878.0
# 4             3  ...       -88       -88     -88   0.032   44878.0
#
#    people_vaccinated  people_vaccinated_per_hundred  people_fully_vaccinated  \
# ...
